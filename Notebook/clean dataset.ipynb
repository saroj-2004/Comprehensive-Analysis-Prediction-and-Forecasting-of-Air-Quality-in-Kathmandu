# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv(r'C:\Projects\DSproject\Data\data.csv')
data2 = pd.read_csv(r'C:\Projects\DSproject\Data\data2.csv')

# %%
data1
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2                    478.0
# 1      2022-08-05T01:00          29.7           20.8                    435.0
# 2      2022-08-05T02:00          25.3           17.7                    374.0
# 3      2022-08-05T03:00          23.1           16.2                    303.0
# 4      2022-08-05T04:00          20.3           14.2                    272.0
# ...                 ...           ...            ...                      ...
# 22531  2025-02-28T19:00          49.1           29.6                    780.0
# 22532  2025-02-28T20:00          46.4           28.2                    652.0
# 22533  2025-02-28T21:00          44.2           27.1                    548.0
# 22534  2025-02-28T22:00          42.4           26.0                    489.0
# 22535  2025-02-28T23:00          42.8           26.7                    455.0
#
#        carbon_dioxide (ppm)  nitrogen_dioxide (μg/m³)  \
# 0                       NaN                      14.1
# 1                       NaN                      11.6
# 2                       NaN                       8.2
# 3                       NaN                       4.3
# 4                       NaN                       2.9
# ...                     ...                       ...
# 22531                 457.0                      13.4
# 22532                 457.0                      11.1
# 22533                 457.0                       9.6
# 22534                 456.0                       9.1
# 22535                 455.0                       9.3
#
#        sulphur_dioxide (μg/m³)  us_aqi (USAQI)
# 0                          5.2              58
# 1                          4.5              59
# 2                          3.5              59
# 3                          2.5              60
# 4                          2.0              60
# ...                        ...             ...
# 22531                      7.8             153
# 22532                      7.5             151
# 22533                      7.2             146
# 22534                      6.9             137
# 22535                      6.8             128
#
# [22536 rows x 8 columns]

# %%
data2
# Out:
#                    time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0      2022-08-05T00:00                 20.3                      98.0
# 1      2022-08-05T01:00                 21.0                      96.0
# 2      2022-08-05T02:00                 21.7                      93.0
# 3      2022-08-05T03:00                 23.2                      86.0
# 4      2022-08-05T04:00                 25.1                      76.0
# ...                 ...                  ...                       ...
# 22531  2025-02-28T19:00                  NaN                       NaN
# 22532  2025-02-28T20:00                  NaN                       NaN
# 22533  2025-02-28T21:00                  NaN                       NaN
# 22534  2025-02-28T22:00                  NaN                       NaN
# 22535  2025-02-28T23:00                  NaN                       NaN
#
#        apparent_temperature (°C)  wind_speed_10m (km/h)  \
# 0                           23.7                    3.1
# 1                           24.8                    1.8
# 2                           25.4                    3.1
# 3                           27.0                    3.1
# 4                           28.9                    2.1
# ...                          ...                    ...
# 22531                        NaN                    NaN
# 22532                        NaN                    NaN
# 22533                        NaN                    NaN
# 22534                        NaN                    NaN
# 22535                        NaN                    NaN
#
#        wind_speed_100m (km/h)  soil_moisture_0_to_7cm (m³/m³)  \
# 0                         4.4                           0.426
# 1                         3.0                           0.425
# 2                         4.4                           0.424
# 3                         4.0                           0.423
# 4                         2.6                           0.421
# ...                       ...                             ...
# 22531                     NaN                             NaN
# 22532                     NaN                             NaN
# 22533                     NaN                             NaN
# 22534                     NaN                             NaN
# 22535                     NaN                             NaN
#
#        soil_moisture_7_to_28cm (m³/m³)
# 0                                0.429
# 1                                0.428
# 2                                0.427
# 3                                0.426
# 4                                0.425
# ...                                ...
# 22531                              NaN
# 22532                              NaN
# 22533                              NaN
# 22534                              NaN
# 22535                              NaN
#
# [22536 rows x 8 columns]

# %%
data2 = data2.drop(columns=["apparent_temperature (°C)", "wind_speed_100m (km/h)", "soil_moisture_7_to_28cm (m³/m³)"])
data1 = data1.drop(columns=["carbon_dioxide (ppm)"])

# %%
data1
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2                    478.0
# 1      2022-08-05T01:00          29.7           20.8                    435.0
# 2      2022-08-05T02:00          25.3           17.7                    374.0
# 3      2022-08-05T03:00          23.1           16.2                    303.0
# 4      2022-08-05T04:00          20.3           14.2                    272.0
# ...                 ...           ...            ...                      ...
# 22531  2025-02-28T19:00          49.1           29.6                    780.0
# 22532  2025-02-28T20:00          46.4           28.2                    652.0
# 22533  2025-02-28T21:00          44.2           27.1                    548.0
# 22534  2025-02-28T22:00          42.4           26.0                    489.0
# 22535  2025-02-28T23:00          42.8           26.7                    455.0
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  us_aqi (USAQI)
# 0                          14.1                      5.2              58
# 1                          11.6                      4.5              59
# 2                           8.2                      3.5              59
# 3                           4.3                      2.5              60
# 4                           2.9                      2.0              60
# ...                         ...                      ...             ...
# 22531                      13.4                      7.8             153
# 22532                      11.1                      7.5             151
# 22533                       9.6                      7.2             146
# 22534                       9.1                      6.9             137
# 22535                       9.3                      6.8             128
#
# [22536 rows x 7 columns]

# %%
# Merge both datasets on 'time' column
merged_df = pd.merge(data1, data2, on="time", how="inner")  # 'inner' join to keep only matching rows
merged_df
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2                    478.0
# 1      2022-08-05T01:00          29.7           20.8                    435.0
# 2      2022-08-05T02:00          25.3           17.7                    374.0
# 3      2022-08-05T03:00          23.1           16.2                    303.0
# 4      2022-08-05T04:00          20.3           14.2                    272.0
# ...                 ...           ...            ...                      ...
# 22531  2025-02-28T19:00          49.1           29.6                    780.0
# 22532  2025-02-28T20:00          46.4           28.2                    652.0
# 22533  2025-02-28T21:00          44.2           27.1                    548.0
# 22534  2025-02-28T22:00          42.4           26.0                    489.0
# 22535  2025-02-28T23:00          42.8           26.7                    455.0
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  us_aqi (USAQI)  \
# 0                          14.1                      5.2              58
# 1                          11.6                      4.5              59
# 2                           8.2                      3.5              59
# 3                           4.3                      2.5              60
# 4                           2.9                      2.0              60
# ...                         ...                      ...             ...
# 22531                      13.4                      7.8             153
# 22532                      11.1                      7.5             151
# 22533                       9.6                      7.2             146
# 22534                       9.1                      6.9             137
# 22535                       9.3                      6.8             128
#
#        temperature_2m (°C)  relative_humidity_2m (%)  wind_speed_10m (km/h)  \
# 0                     20.3                      98.0                    3.1
# 1                     21.0                      96.0                    1.8
# 2                     21.7                      93.0                    3.1
# 3                     23.2                      86.0                    3.1
# 4                     25.1                      76.0                    2.1
# ...                    ...                       ...                    ...
# 22531                  NaN                       NaN                    NaN
# 22532                  NaN                       NaN                    NaN
# 22533                  NaN                       NaN                    NaN
# 22534                  NaN                       NaN                    NaN
# 22535                  NaN                       NaN                    NaN
#
#        soil_moisture_0_to_7cm (m³/m³)
# 0                               0.426
# 1                               0.425
# 2                               0.424
# 3                               0.423
# 4                               0.421
# ...                               ...
# 22531                             NaN
# 22532                             NaN
# 22533                             NaN
# 22534                             NaN
# 22535                             NaN
#
# [22536 rows x 11 columns]

# %%
# Drop the 'time' column before computing the correlation matrix
df_numeric = merged_df.drop(columns=['time'])

plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
merged_df['AQI'] = merged_df['us_aqi (USAQI)']

# %%
merged_df
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2                    478.0
# 1      2022-08-05T01:00          29.7           20.8                    435.0
# 2      2022-08-05T02:00          25.3           17.7                    374.0
# 3      2022-08-05T03:00          23.1           16.2                    303.0
# 4      2022-08-05T04:00          20.3           14.2                    272.0
# ...                 ...           ...            ...                      ...
# 22531  2025-02-28T19:00          49.1           29.6                    780.0
# 22532  2025-02-28T20:00          46.4           28.2                    652.0
# 22533  2025-02-28T21:00          44.2           27.1                    548.0
# 22534  2025-02-28T22:00          42.4           26.0                    489.0
# 22535  2025-02-28T23:00          42.8           26.7                    455.0
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  us_aqi (USAQI)  \
# 0                          14.1                      5.2              58
# 1                          11.6                      4.5              59
# 2                           8.2                      3.5              59
# 3                           4.3                      2.5              60
# 4                           2.9                      2.0              60
# ...                         ...                      ...             ...
# 22531                      13.4                      7.8             153
# 22532                      11.1                      7.5             151
# 22533                       9.6                      7.2             146
# 22534                       9.1                      6.9             137
# 22535                       9.3                      6.8             128
#
#        temperature_2m (°C)  relative_humidity_2m (%)  wind_speed_10m (km/h)  \
# 0                     20.3                      98.0                    3.1
# 1                     21.0                      96.0                    1.8
# 2                     21.7                      93.0                    3.1
# 3                     23.2                      86.0                    3.1
# 4                     25.1                      76.0                    2.1
# ...                    ...                       ...                    ...
# 22531                  NaN                       NaN                    NaN
# 22532                  NaN                       NaN                    NaN
# 22533                  NaN                       NaN                    NaN
# 22534                  NaN                       NaN                    NaN
# 22535                  NaN                       NaN                    NaN
#
#        soil_moisture_0_to_7cm (m³/m³)  AQI
# 0                               0.426   58
# 1                               0.425   59
# 2                               0.424   59
# 3                               0.423   60
# 4                               0.421   60
# ...                               ...  ...
# 22531                             NaN  153
# 22532                             NaN  151
# 22533                             NaN  146
# 22534                             NaN  137
# 22535                             NaN  128
#
# [22536 rows x 12 columns]

# %%
merged_df = merged_df.drop(columns=["us_aqi (USAQI)"])

# %%
merged_df
# Out:
#                    time  pm10 (μg/m³)  pm2_5 (μg/m³)  carbon_monoxide (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2                    478.0
# 1      2022-08-05T01:00          29.7           20.8                    435.0
# 2      2022-08-05T02:00          25.3           17.7                    374.0
# 3      2022-08-05T03:00          23.1           16.2                    303.0
# 4      2022-08-05T04:00          20.3           14.2                    272.0
# ...                 ...           ...            ...                      ...
# 22531  2025-02-28T19:00          49.1           29.6                    780.0
# 22532  2025-02-28T20:00          46.4           28.2                    652.0
# 22533  2025-02-28T21:00          44.2           27.1                    548.0
# 22534  2025-02-28T22:00          42.4           26.0                    489.0
# 22535  2025-02-28T23:00          42.8           26.7                    455.0
#
#        nitrogen_dioxide (μg/m³)  sulphur_dioxide (μg/m³)  temperature_2m (°C)  \
# 0                          14.1                      5.2                 20.3
# 1                          11.6                      4.5                 21.0
# 2                           8.2                      3.5                 21.7
# 3                           4.3                      2.5                 23.2
# 4                           2.9                      2.0                 25.1
# ...                         ...                      ...                  ...
# 22531                      13.4                      7.8                  NaN
# 22532                      11.1                      7.5                  NaN
# 22533                       9.6                      7.2                  NaN
# 22534                       9.1                      6.9                  NaN
# 22535                       9.3                      6.8                  NaN
#
#        relative_humidity_2m (%)  wind_speed_10m (km/h)  \
# 0                          98.0                    3.1
# 1                          96.0                    1.8
# 2                          93.0                    3.1
# 3                          86.0                    3.1
# 4                          76.0                    2.1
# ...                         ...                    ...
# 22531                       NaN                    NaN
# 22532                       NaN                    NaN
# 22533                       NaN                    NaN
# 22534                       NaN                    NaN
# 22535                       NaN                    NaN
#
#        soil_moisture_0_to_7cm (m³/m³)  AQI
# 0                               0.426   58
# 1                               0.425   59
# 2                               0.424   59
# 3                               0.423   60
# 4                               0.421   60
# ...                               ...  ...
# 22531                             NaN  153
# 22532                             NaN  151
# 22533                             NaN  146
# 22534                             NaN  137
# 22535                             NaN  128
#
# [22536 rows x 11 columns]

# %%
# Rename columns with shorter names
merged_df = merged_df.rename(columns={
    'time': 'time',
    'pm10 (μg/m³)': 'PM10 (μg/m³)',
    'pm2_5 (μg/m³)': 'PM2.5 (μg/m³)',
    'carbon_monoxide (μg/m³)': 'CO (μg/m³)',
    'nitrogen_dioxide (μg/m³)': 'NO2 (μg/m³)',
    'sulphur_dioxide (μg/m³)': 'SO2 (μg/m³)',
    'temperature_2m (°C)': 'Temp (°C)',
    'relative_humidity_2m (%)': 'Humidity (%)',
    'wind_speed_10m (km/h)': 'Wind_Speed (km/h)',
    'soil_moisture_0_to_7cm (m³/m³)': 'Soil_Moisture (m³/m³)',
    'AQI': 'AQI'
})

# %%
merged_df
# Out:
#                    time  PM10 (μg/m³)  PM2.5 (μg/m³)  CO (μg/m³)  NO2 (μg/m³)  \
# 0      2022-08-05T00:00          31.7           22.2       478.0         14.1
# 1      2022-08-05T01:00          29.7           20.8       435.0         11.6
# 2      2022-08-05T02:00          25.3           17.7       374.0          8.2
# 3      2022-08-05T03:00          23.1           16.2       303.0          4.3
# 4      2022-08-05T04:00          20.3           14.2       272.0          2.9
# ...                 ...           ...            ...         ...          ...
# 22531  2025-02-28T19:00          49.1           29.6       780.0         13.4
# 22532  2025-02-28T20:00          46.4           28.2       652.0         11.1
# 22533  2025-02-28T21:00          44.2           27.1       548.0          9.6
# 22534  2025-02-28T22:00          42.4           26.0       489.0          9.1
# 22535  2025-02-28T23:00          42.8           26.7       455.0          9.3
#
#        SO2 (μg/m³)  Temp (°C)  Humidity (%)  Wind_Speed (km/h)  \
# 0              5.2       20.3          98.0                3.1
# 1              4.5       21.0          96.0                1.8
# 2              3.5       21.7          93.0                3.1
# 3              2.5       23.2          86.0                3.1
# 4              2.0       25.1          76.0                2.1
# ...            ...        ...           ...                ...
# 22531          7.8        NaN           NaN                NaN
# 22532          7.5        NaN           NaN                NaN
# 22533          7.2        NaN           NaN                NaN
# 22534          6.9        NaN           NaN                NaN
# 22535          6.8        NaN           NaN                NaN
#
#        Soil_Moisture (m³/m³)  AQI
# 0                      0.426   58
# 1                      0.425   59
# 2                      0.424   59
# 3                      0.423   60
# 4                      0.421   60
# ...                      ...  ...
# 22531                    NaN  153
# 22532                    NaN  151
# 22533                    NaN  146
# 22534                    NaN  137
# 22535                    NaN  128
#
# [22536 rows x 11 columns]

# %%
merged_df['Date'] = pd.to_datetime(merged_df['time']).dt.date
merged_df['Time'] = pd.to_datetime(merged_df['time']).dt.time

# Drop the original 'time' column if it's no longer needed
merged_df = merged_df.drop(columns=['time'])
columns = ['Date', 'Time'] + [col for col in merged_df.columns if col not in ['Date', 'Time']]
merged_df = merged_df[columns]

# %%
merged_df
# Out:
#              Date      Time  PM10 (μg/m³)  PM2.5 (μg/m³)  CO (μg/m³)  \
# 0      2022-08-05  00:00:00          31.7           22.2       478.0
# 1      2022-08-05  01:00:00          29.7           20.8       435.0
# 2      2022-08-05  02:00:00          25.3           17.7       374.0
# 3      2022-08-05  03:00:00          23.1           16.2       303.0
# 4      2022-08-05  04:00:00          20.3           14.2       272.0
# ...           ...       ...           ...            ...         ...
# 22531  2025-02-28  19:00:00          49.1           29.6       780.0
# 22532  2025-02-28  20:00:00          46.4           28.2       652.0
# 22533  2025-02-28  21:00:00          44.2           27.1       548.0
# 22534  2025-02-28  22:00:00          42.4           26.0       489.0
# 22535  2025-02-28  23:00:00          42.8           26.7       455.0
#
#        NO2 (μg/m³)  SO2 (μg/m³)  Temp (°C)  Humidity (%)  Wind_Speed (km/h)  \
# 0             14.1          5.2       20.3          98.0                3.1
# 1             11.6          4.5       21.0          96.0                1.8
# 2              8.2          3.5       21.7          93.0                3.1
# 3              4.3          2.5       23.2          86.0                3.1
# 4              2.9          2.0       25.1          76.0                2.1
# ...            ...          ...        ...           ...                ...
# 22531         13.4          7.8        NaN           NaN                NaN
# 22532         11.1          7.5        NaN           NaN                NaN
# 22533          9.6          7.2        NaN           NaN                NaN
# 22534          9.1          6.9        NaN           NaN                NaN
# 22535          9.3          6.8        NaN           NaN                NaN
#
#        Soil_Moisture (m³/m³)  AQI
# 0                      0.426   58
# 1                      0.425   59
# 2                      0.424   59
# 3                      0.423   60
# 4                      0.421   60
# ...                      ...  ...
# 22531                    NaN  153
# 22532                    NaN  151
# 22533                    NaN  146
# 22534                    NaN  137
# 22535                    NaN  128
#
# [22536 rows x 12 columns]

# %%
columns_to_fill = ['Temp (°C)', 'Humidity (%)', 'Wind_Speed (km/h)','Soil_Moisture (m³/m³)']

merged_df[columns_to_fill] = merged_df[columns_to_fill].apply(lambda col: col.fillna(col.mean()))

# %%
merged_df["Datetime"] = pd.to_datetime(merged_df["Date"].astype(str) + " " + merged_df["Time"].astype(str))
merged_df.drop(["Date", "Time"], axis=1, inplace=True)

merged_df.set_index("Datetime", inplace=True)

print(merged_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 22536 entries, 2022-08-05 00:00:00 to 2025-02-28 23:00:00
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PM10 (μg/m³)           22536 non-null  float64
#  1   PM2.5 (μg/m³)          22536 non-null  float64
#  2   CO (μg/m³)             22536 non-null  float64
#  3   NO2 (μg/m³)            22536 non-null  float64
#  4   SO2 (μg/m³)            22536 non-null  float64
#  5   Temp (°C)              22536 non-null  float64
#  6   Humidity (%)           22536 non-null  float64
#  7   Wind_Speed (km/h)      22536 non-null  float64
#  8   Soil_Moisture (m³/m³)  22536 non-null  float64
#  9   AQI                    22536 non-null  int64
# dtypes: float64(9), int64(1)
# memory usage: 1.9 MB
# None

# %%
merged_df
# Out:
#                      PM10 (μg/m³)  PM2.5 (μg/m³)  CO (μg/m³)  NO2 (μg/m³)  \
# Datetime
# 2022-08-05 00:00:00          31.7           22.2       478.0         14.1
# 2022-08-05 01:00:00          29.7           20.8       435.0         11.6
# 2022-08-05 02:00:00          25.3           17.7       374.0          8.2
# 2022-08-05 03:00:00          23.1           16.2       303.0          4.3
# 2022-08-05 04:00:00          20.3           14.2       272.0          2.9
# ...                           ...            ...         ...          ...
# 2025-02-28 19:00:00          49.1           29.6       780.0         13.4
# 2025-02-28 20:00:00          46.4           28.2       652.0         11.1
# 2025-02-28 21:00:00          44.2           27.1       548.0          9.6
# 2025-02-28 22:00:00          42.4           26.0       489.0          9.1
# 2025-02-28 23:00:00          42.8           26.7       455.0          9.3
#
#                      SO2 (μg/m³)  Temp (°C)  Humidity (%)  Wind_Speed (km/h)  \
# Datetime
# 2022-08-05 00:00:00          5.2  20.300000     98.000000           3.100000
# 2022-08-05 01:00:00          4.5  21.000000     96.000000           1.800000
# 2022-08-05 02:00:00          3.5  21.700000     93.000000           3.100000
# 2022-08-05 03:00:00          2.5  23.200000     86.000000           3.100000
# 2022-08-05 04:00:00          2.0  25.100000     76.000000           2.100000
# ...                          ...        ...           ...                ...
# 2025-02-28 19:00:00          7.8  17.919721     74.457112           4.023171
# 2025-02-28 20:00:00          7.5  17.919721     74.457112           4.023171
# 2025-02-28 21:00:00          7.2  17.919721     74.457112           4.023171
# 2025-02-28 22:00:00          6.9  17.919721     74.457112           4.023171
# 2025-02-28 23:00:00          6.8  17.919721     74.457112           4.023171
#
#                      Soil_Moisture (m³/m³)  AQI
# Datetime
# 2022-08-05 00:00:00               0.426000   58
# 2022-08-05 01:00:00               0.425000   59
# 2022-08-05 02:00:00               0.424000   59
# 2022-08-05 03:00:00               0.423000   60
# 2022-08-05 04:00:00               0.421000   60
# ...                                    ...  ...
# 2025-02-28 19:00:00               0.293815  153
# 2025-02-28 20:00:00               0.293815  151
# 2025-02-28 21:00:00               0.293815  146
# 2025-02-28 22:00:00               0.293815  137
# 2025-02-28 23:00:00               0.293815  128
#
# [22536 rows x 10 columns]

# %%
merged_df.to_csv(r'C:\Projects\DSproject\Data\Air_Quality_dataset_of_kathmandu.csv')
